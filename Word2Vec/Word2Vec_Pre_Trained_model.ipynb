# %%
# https://www.kaggle.com/datasets/leadbest/googlenewsvectorsnegative300
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !kaggle datasets download -d leadbest/googlenewsvectorsnegative300
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/leadbest/googlenewsvectorsnegative300
# License(s): other
# ...
# 100% 3.17G/3.17G [03:36<00:00, 22.2MB/s]
# 100% 3.17G/3.17G [03:36<00:00, 15.7MB/s]

# %%
import zipfile
zip_file = zipfile.ZipFile('/content/googlenewsvectorsnegative300.zip')
zip_file.extractall('/content')
zip_file.close()

# %%
# !pip install gensim

# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
model = KeyedVectors.load_word2vec_format('/content/GoogleNews-vectors-negative300.bin.gz', binary=True, limit = 500000)

# %%
model['happy']
# Out:
# array([-5.18798828e-04,  1.60156250e-01,  1.60980225e-03,  2.53906250e-02,
#         9.91210938e-02, -8.59375000e-02,  3.24218750e-01, -2.17285156e-02,
#         1.34765625e-01,  1.10351562e-01, -1.04980469e-01, -2.90527344e-02,
#        -2.38037109e-02, -4.02832031e-02, -3.68652344e-02,  2.32421875e-01,
#         3.20312500e-01,  1.01074219e-01,  5.83496094e-02, -2.91824341e-04,
#        -3.29589844e-02,  2.11914062e-01,  4.32128906e-02, -8.59375000e-02,
#         2.81250000e-01, -1.78222656e-02,  3.79943848e-03, -1.71875000e-01,
#         2.06054688e-01, -1.85546875e-01,  3.73535156e-02, -1.21459961e-02,
#         2.04101562e-01, -3.80859375e-02,  3.61328125e-02, -8.15429688e-02,
#         8.44726562e-02,  9.37500000e-02,  1.44531250e-01,  7.42187500e-02,
#         2.51953125e-01, -7.91015625e-02,  8.69140625e-02,  1.58691406e-02,
#         1.09375000e-01, -2.23632812e-01, -5.15747070e-03,  1.68945312e-01,
# ...

# %%
model['enjoy']
# Out:
# array([-1.25885010e-03, -4.83398438e-02, -2.83203125e-01,  3.24218750e-01,
#         1.44653320e-02,  1.27929688e-01,  1.94335938e-01, -5.95703125e-02,
#        -1.53320312e-01,  1.86523438e-01, -1.00097656e-01, -2.61718750e-01,
#        -1.36718750e-02,  6.98242188e-02,  3.12500000e-02,  2.19726562e-01,
#         1.60156250e-01,  1.64062500e-01,  2.85156250e-01, -4.24804688e-02,
#        -1.42578125e-01,  1.91406250e-01,  8.98437500e-02,  1.82617188e-01,
#         1.25976562e-01, -5.05371094e-02,  4.22363281e-02,  1.14257812e-01,
#        -9.71679688e-02, -1.18652344e-01, -7.47070312e-02, -3.46679688e-02,
#        -8.30078125e-02,  2.06054688e-01,  7.56835938e-02, -9.47265625e-02,
#        -2.70996094e-02, -2.87109375e-01,  8.39843750e-02,  3.41796875e-01,
#         6.44531250e-02,  2.39257812e-02,  1.47460938e-01,  1.66992188e-01,
#        -1.04980469e-01, -2.73437500e-01, -1.26953125e-01,  6.29882812e-02,
# ...

# %%
model.similarity('happy','enjoy')
# Out:
# 0.3910905

# %%
model.similarity('happy','football')
# Out:
# 0.11925444

# %%
model.similarity('king','queen')
# Out:
# 0.6510956

# %%
model.similarity('happy','joy')
# Out:
# 0.35500747

# %%
model.similarity('Modi','Rahul')
# Out:
# 0.70939004

# %%
model.most_similar('Modi')
# Out:
# [('Narendra_Modi', 0.8249751329421997),
#  ('Pawar', 0.7882996797561646),
#  ('Advani', 0.770244836807251),
#  ('Dalmiya', 0.7563172578811646),
#  ('Lalit_Modi', 0.7458745241165161),
#  ('Jaitley', 0.740410327911377),
#  ('Deshmukh', 0.7383387088775635),
#  ('Gadkari', 0.7377651929855347),
#  ('BJP', 0.722312867641449),
#  ('Bhujbal', 0.7218786478042603)]

# %%
model.most_similar('Rahul')
# Out:
# [('Sanjay', 0.7713990211486816),
#  ('Rahul_Gandhi', 0.7693262696266174),
#  ('Priyanka', 0.7578054666519165),
#  ('Advani', 0.7462595105171204),
#  ('Varun', 0.7435700297355652),
#  ('Mamta', 0.74252849817276),
#  ('Rohit', 0.7390825748443604),
#  ('Nitish', 0.738690972328186),
#  ('Shukla', 0.7367516756057739),
#  ('Deshmukh', 0.7348041534423828)]

# %%
len(model['happy'])
# Out:
# 300

# %%
model['cricket']
# Out:
# array([-3.67187500e-01, -1.21582031e-01,  2.85156250e-01,  8.15429688e-02,
#         3.19824219e-02, -3.19824219e-02,  1.34765625e-01, -2.73437500e-01,
#         9.46044922e-03, -1.07421875e-01,  2.48046875e-01, -6.05468750e-01,
#         5.02929688e-02,  2.98828125e-01,  9.57031250e-02,  1.39648438e-01,
#        -5.41992188e-02,  2.91015625e-01,  2.85156250e-01,  1.51367188e-01,
#        -2.89062500e-01, -3.46679688e-02,  1.81884766e-02, -3.92578125e-01,
#         2.46093750e-01,  2.51953125e-01, -9.86328125e-02,  3.22265625e-01,
#         4.49218750e-01, -1.36718750e-01, -2.34375000e-01,  4.12597656e-02,
#        -2.15820312e-01,  1.69921875e-01,  2.56347656e-02,  1.50146484e-02,
#        -3.75976562e-02,  6.95800781e-03,  4.00390625e-01,  2.09960938e-01,
#         1.17675781e-01, -4.19921875e-02,  2.34375000e-01,  2.03125000e-01,
#        -1.86523438e-01, -2.46093750e-01,  3.12500000e-01, -2.59765625e-01,
# ...

# %%
model['politics']
# Out:
# array([ 1.56250000e-01,  2.89306641e-02, -5.59082031e-02,  1.91406250e-01,
#        -1.26342773e-02, -3.17382812e-02, -2.95410156e-02, -5.44433594e-02,
#         1.08886719e-01, -2.45117188e-01,  9.52148438e-02, -1.15234375e-01,
#        -1.71875000e-01,  1.37695312e-01, -2.50000000e-01,  2.73437500e-01,
#         2.09960938e-01,  1.46484375e-01,  1.83593750e-01, -2.85156250e-01,
#        -9.03320312e-02,  9.21630859e-03,  7.71484375e-02, -1.26953125e-01,
#        -1.40625000e-01,  8.30078125e-03,  1.12304688e-01, -2.45361328e-02,
#         4.21875000e-01,  1.25732422e-02, -8.48388672e-03,  1.47460938e-01,
#         4.39453125e-02,  2.77343750e-01,  1.46484375e-01,  6.64062500e-02,
#         1.13769531e-01,  2.07031250e-01,  1.25976562e-01,  1.70898438e-01,
#         7.71484375e-02, -2.05078125e-01,  1.24023438e-01,  6.29882812e-02,
#        -2.81250000e-01,  1.32812500e-01,  6.34765625e-02,  3.14941406e-02,
# ...

# %%
model['abracadabra']
# Out:
# array([ 0.2421875 ,  0.23925781,  0.09667969,  0.20605469, -0.14160156,
#        -0.12451172,  0.08056641, -0.12890625, -0.02819824,  0.07080078,
#         0.04174805, -0.00457764, -0.24511719,  0.19238281, -0.13671875,
#         0.47070312,  0.23046875, -0.02380371,  0.30859375, -0.2734375 ,
#         0.02563477, -0.08496094,  0.11962891, -0.11914062, -0.09228516,
#         0.01599121,  0.07763672, -0.31054688,  0.0291748 , -0.14746094,
#        -0.09082031, -0.01208496,  0.00085831, -0.01092529,  0.01586914,
#         0.08203125,  0.25976562, -0.07568359,  0.26757812,  0.04663086,
#         0.125     , -0.15820312,  0.23339844,  0.01196289, -0.01757812,
#        -0.28320312, -0.19335938, -0.07373047, -0.1328125 ,  0.2421875 ,
#        -0.47460938,  0.12109375,  0.13671875,  0.04272461,  0.19433594,
#         0.23828125,  0.08056641, -0.44726562, -0.08349609, -0.20507812,
#         0.03039551,  0.12158203,  0.18261719, -0.02148438,  0.06005859,
# ...

# %%
model.most_similar('happy')
# Out:
# [('glad', 0.7408890724182129),
#  ('pleased', 0.6632170677185059),
#  ('ecstatic', 0.6626912355422974),
#  ('overjoyed', 0.6599286794662476),
#  ('thrilled', 0.6514049172401428),
#  ('satisfied', 0.6437949538230896),
#  ('proud', 0.636042058467865),
#  ('delighted', 0.627237856388092),
#  ('disappointed', 0.6269949674606323),
#  ('excited', 0.6247665286064148)]

# %%
model.doesnt_match(['Rahul','Python','Java'])
# Out:
# 'Rahul'

# %%
model.doesnt_match(['Rahul','Modi','Java'])
# Out:
# 'Java'

# %%
vec = model['King'] - model['Man'] + model['Woman']
model.most_similar(vec)
# Out:
# [('King', 0.5864337682723999),
#  ('Woman', 0.4632062017917633),
#  ('Queen', 0.4424014389514923),
#  ('Daughters', 0.41669827699661255),
#  ('Coretta_King', 0.4024410843849182),
#  ('queen', 0.40151089429855347),
#  ('her', 0.3993203043937683),
#  ('Women', 0.3983253240585327),
#  ('she', 0.38977766036987305),
#  ('Coretta_Scott_King', 0.3845826983451843)]

# %%
vec = model['India'] - model['INR'] + model['England'] + model['USA']
model.most_similar(vec)
# Out:
# [('England', 0.7203639149665833),
#  ('USA', 0.6605732440948486),
#  ('Great_Britain', 0.5760036110877991),
#  ('Britain', 0.5421634316444397),
#  ('India', 0.5238601565361023),
#  ('United_States', 0.5142343640327454),
#  ('Australia', 0.5102094411849976),
#  ('United_Kingdom', 0.5037966370582581),
#  ('Canada', 0.4933895468711853),
#  ('Britian', 0.4739449918270111)]
